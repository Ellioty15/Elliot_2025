# %% [markdown]
# ---
# comments: true
# layout: post
# title: Final Blog
# description: My final blog for 2024-2025 AP computer science principles
# ---

# %% [markdown]
# ### Homework Hacks
#
# | Topic                             | Homework Link                                                                 |
# |----------------------------------|-------------------------------------------------------------------------------|
# | Beneficial and Harmful Effects of Computing | [5.1 Homework]({{site.baseurl}}/5.1_homework/)                      |
# | Digital Divide                   | [5.2 Homework Hacks]({{site.baseurl}}/5.2_homework/)                         |
# | Computing Bias                   | [5.3 Homework Hack]({{site.baseurl}}/5.3_homework/)                          |
# | Crowd Sourcing                   | [5.4 Homework Hacks]({{site.baseurl}}/5.4_homework/)                         |
# | Legal and Ethical Concerns       | [5.5 Homework Hacks]({{site.baseurl}}/5.5_homework/)                         |
# | Styling                          | [Base64 Homework Hacks]({{site.baseurl}}/base64_homework/)                  |
# | Binary Search Algorithms         | [Binary Search Homework Hacks]({{site.baseurl}}/binary_homework/)           |
# | Lists                            | [3.2 Homework Hacks]({{site.baseurl}}/3.2_homework/)                         |
# | Random Algorithms                | [3.9 Homework Hacks]({{site.baseurl}}/3.9_homework/)                         |
# | Big O                            | [3.17 Homework Hacks]({{site.baseurl}}/3.17_teamteach/)                      |
# | Undecidable                      | [3.18/19 Homework Hacks]({{site.baseurl}}/3.18_homework/)                    |
# | Binary                           | [3.11 Homework Hacks]({{site.baseurl}}/3.11_homework/)                       |
# | Logic Gates                      | [Logic Gate Popcorn Hacks]({{site.baseurl}}/logic_homework/)                |
# | Base64                           | [Base64 Homework Hacks]({{site.baseurl}}/base64_homework/)                  |
#
# <br>
# ---
# <br>
#
# ### LinkedIn
#
# #### Professional Profile
#
# Connect with me on [LinkedIn](https://www.linkedin.com/in/elliot-yang-841686368) to explore my professional journey, skills, and experiences.
#
# <div style="display: flex; align-items: center; gap: 1.5rem; flex-wrap: wrap; margin-top: 1rem;">
#
# <img src="{{site.baseurl}}/images/linklogo.png" alt="LinkedIn Logo" width="100" style="border-radius: 8px;">
#
# <div>
#
# **Key Highlights:**
# - Project Experience
# - Technical Skills
# - Personal Skills
# - Professional Connections
#
# </div>
# </div>
#
#
#
# <br>
# ---
# <br>
#
# # Coding and My Interests
# ## Automation
# I'm fascinated by how coding can eliminate repetitive tasks. I've used scripts to automate workflows, clean up data, and saw how it was possible to create code that eliminated the need to do repetitive tasks.
#
# ## Social Media
# Coding and Social media relate because videos are recommended based on machine learning, and its important to understand the data in order to grow on social media. From analyzing engagement data to building dashboards that track performance, I'm exploring how tech can turn content into strategy.
#
# ## Summary
# I think something that would be interesting to try would be to automate video creation using code.
#
#
# <br>
# ---
# <br>
#
# # Stats
#
# [Issues](https://github.com/Ellioty15/Elliot_2025/issues)
#
# ## Commits:
# <img src="{{site.baseurl}}/images/commits.png" alt="Commits" width="800" style="border-radius: 8px;">
# ## Analytics seen on Open Coding Society:
# <img src="{{site.baseurl}}/images/OCSanalytics.png" alt="My Github Stats seen on OCS" width="800" style="border-radius: 8px;">
# ## Grade Predictor:
# <img src="{{site.baseurl}}/images/gradepredictor.png" alt="My predicted grade through Open Coding Society" width="800" style="border-radius: 8px;">
#
# <br>
# ---
# <br>
# # My project timeline
#
# ## First Project
# - Personal Repository
#     - familiarized myself with github
#     - learned how to make new files in a repository
#     - learned how to work in scrum groups
#
# ## Second Project
# - Frostbyte
#     - Used a Kanban Board and created personal Burndowns
# <img src="{{site.baseurl}}/images/kanbanboard.png" alt="Kanban Board" width="800" style="border-radius: 8px;">
#     - Created an API in the backend
#     - Used Postman API to check that API was functional
# <img src="{{site.baseurl}}/images/postmanupdate.png" alt="Postman Update" width="800" style="border-radius: 8px;">
#
#     - Created frontend fetch functions
#     - Created model code that would store data in SQLite Database
# <img src="{{site.baseurl}}/images/aidatabase.png" alt="AI Database" width="800" style="border-radius: 8px;">
#
#     - Led group efforts for Gemini API
# <img src="{{site.baseurl}}/images/chatbox.png" alt="Chatbox" width="800" style="border-radius: 8px;">
#
#
# ## Final Project
# - Medipulse
#     - Collected data from different sources as CSV files
# <img src="{{site.baseurl}}/images/Medipulsecsv.png" alt="Medipulsecsv" width="800" style="border-radius: 8px;">
#
#     - Created two APIs in the backend
# <img src="{{site.baseurl}}/images/youtubeanalytics.png" alt="youtube analytics" width="800" style="border-radius: 8px;">
#
#     - used APIs to display data in the frontend
#     - Styled using tailwind
#     - Used Roadmaps and constantly revised ideations
# <img src="{{site.baseurl}}/images/roadmap.png" alt="Medipulse roadmap" width="800" style="border-radius: 8px;">
#     - [Created Documentation and planned for the group](https://github.com/users/GavinCopley/projects/4/views/1?pane=issue&itemId=109859307&issue=GavinCopley%7CMediPulse%7C41)
#
# <br>
# ---
# <br>
#
# # N@tM Experience
# <img src="{{site.baseurl}}/images/N@tM1.jpg" alt="N@tM teaching proof" width="800" style="border-radius: 8px;">
# <img src="{{site.baseurl}}/images/N@tM2.jpg" alt="N@tM teaching proof" width="800" style="border-radius: 8px;">
# <img src="{{site.baseurl}}/images/N@tM3.jpg" alt="N@tM teaching proof" width="800" style="border-radius: 8px;">
#
# <br>
# ---
# <br>
# # My next steps
# ## Pilot City
#
# I was able to earn an internship position with Pilot City, and I’m excited to use this opportunity to expand my coding knowledge while building real-world experience. This internship is a chance to work on projects that matter and strengthen my resume with hands-on development work. I'm looking forward to collaborating with others and seeing how tech can solve real problems in industry.
#
# ## AP CSA
#
# I’m planning to take AP Computer Science A next year. I see it as a key step in building my foundation in computer science. I’m excited to dive into Java, learn about data structures, algorithms, and object-oriented programming, and apply those concepts to my own projects.
#
# ## Looking for More Opportunities
#
# Whether it’s internships, side projects, or collaborating with others, I’m always looking for ways to grow. I want to explore more opportunities where I can build cool stuff, contribute to real teams, and push myself outside my comfort zone. Every experience I take on now is an investment into where I want to be later—and I’m jus
